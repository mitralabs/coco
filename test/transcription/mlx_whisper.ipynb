# %% [markdown]
# ## [Github Repo](https://github.com/ml-explore/mlx-examples)

# %% [markdown]
# ## [HF Community](https://huggingface.co/mlx-community)

# %%
# !pip install mlx-whisper
# Out:
# ...
#   Using cached numba-0.60.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.7 kB)
# ...
#   Using cached tiktoken-0.8.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# ...
#   Using cached PyYAML-6.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.1 kB)
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached llvmlite-0.43.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.8 kB)
# ...
#   Using cached numpy-2.0.2-cp311-cp311-macosx_14_0_arm64.whl.metadata (60 kB)
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached certifi-2024.12.14-py3-none-any.whl.metadata (2.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 782.4/782.4 kB 364.1 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 118.5 kB/s eta 0:00:0000:0100:06
# ...
# Using cached numba-0.60.0-cp311-cp311-macosx_11_0_arm64.whl (2.6 MB)
# ...

# %%
# !pip install huggingface_hub

# %%
import mlx_whisper

file_name = "audio/all_sessions/session_25_speech.wav"

result = mlx_whisper.transcribe(
    file_name,
    path_or_hf_repo="models/whisper-base-mlx-4bit",
)

# %%
print(result)
# Out:
# {'text': ' Ich bin schon bei mir eigentlich aufladen. Auf ich mache das sehr akuschelle jetzt richtig. Ich meine die Idee zu Netkimps. Ich stelle mir hin und wieder die Frage an anderen Personen. Netkimps als Herbst zu legen, damit diese Personen ebenfalls anfangen, die die ihnen die Schweißern, damit sie in einer Zeit, der sich mit dieser Person reden kann, der noch etwas mitbekommen, um mit zu lichtigen, die Danklich beschäftigt, schräg, was sie gelesen oder was sie gehört hat, was wollen. Das würde mich bei einem alten Person sein, das hier noch viel mehr als ein Vorsitzung. Es geht in die Richtung eines früheren Terrass, wo es keine Bilder oder so, da gab es eine sehr kleines Interfett. Und gleichzeitig kann man das bestehenden Interfett nutzen. Wir haben bei jeder Idee schon einen Batten, der gerade für die Idee bookmarkt, dass sie einem etwas bedeutet. Und man könnte diesen Batten umfunken, dass man die Idee teilt. Hier ist es, kann man sie auch herzen. Oder den Jürgen ein ande
# ...

# %%
output = mlx_whisper.transcribe(speech_file, word_timestamps=True)
print(output["segments"][0]["words"])
