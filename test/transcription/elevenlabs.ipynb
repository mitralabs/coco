# %%
# !pip install elevenlabs python-dotenv
# Out:
# Requirement already satisfied: elevenlabs in c:\users\alex-\miniconda3\envs\coco\lib\site-packages (1.54.0)
# Requirement already satisfied: python-dotenv in c:\users\alex-\miniconda3\envs\coco\lib\site-packages (1.0.1)
# Requirement already satisfied: httpx>=0.21.2 in c:\users\alex-\miniconda3\envs\coco\lib\site-packages (from elevenlabs) (0.28.1)
# Requirement already satisfied: pydantic>=1.9.2 in c:\users\alex-\miniconda3\envs\coco\lib\site-packages (from elevenlabs) (2.10.3)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in c:\users\alex-\miniconda3\envs\coco\lib\site-packages (from elevenlabs) (2.27.1)
# Requirement already satisfied: requests>=2.20 in c:\users\alex-\miniconda3\envs\coco\lib\site-packages (from elevenlabs) (2.32.3)
# Requirement already satisfied: typing_extensions>=4.0.0 in c:\users\alex-\miniconda3\envs\coco\lib\site-packages (from elevenlabs) (4.12.2)
# Requirement already satisfied: websockets>=11.0 in c:\users\alex-\miniconda3\envs\coco\lib\site-packages (from elevenlabs) (12.0)
# Requirement already satisfied: anyio in c:\users\alex-\miniconda3\envs\coco\lib\site-packages (from httpx>=0.21.2->elevenlabs) (3.7.1)
# Requirement already satisfied: certifi in c:\users\alex-\miniconda3\envs\coco\lib\site-packages (from httpx>=0.21.2->elevenlabs) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\alex-\miniconda3\envs\coco\lib\site-packages (from httpx>=0.21.2->elevenlabs) (1.0.7)
# Requirement already satisfied: idna in c:\users\alex-\miniconda3\envs\coco\lib\site-packages (from httpx>=0.21.2->elevenlabs) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\alex-\miniconda3\envs\coco\lib\site-packages (from httpcore==1.*->httpx>=0.21.2->elevenlabs) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\alex-\miniconda3\envs\coco\lib\site-packages (from pydantic>=1.9.2->elevenlabs) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alex-\miniconda3\envs\coco\lib\site-packages (from requests>=2.20->elevenlabs) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alex-\miniconda3\envs\coco\lib\site-packages (from requests>=2.20->elevenlabs) (2.2.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\alex-\miniconda3\envs\coco\lib\site-packages (from anyio->httpx>=0.21.2->elevenlabs) (1.3.1)
# Requirement already satisfied: exceptiongroup in c:\users\alex-\miniconda3\envs\coco\lib\site-packages (from anyio->httpx>=0.21.2->elevenlabs) (1.2.2)

# %%
from dotenv import load_dotenv
from elevenlabs.client import ElevenLabs

load_dotenv()

client = ElevenLabs(
  api_key="input")

audio = client.text_to_speech.convert(
    text="Ich schreibe einen Test.",
    voice_id="JBFqnCBsd6RMkjVDRZzb",
    model_id="eleven_multilingual_v2",
    output_format="mp3_44100_128",
)

with open("output1.mp3", "wb") as f:
    for chunk in audio:  # Handle the generator object
        f.write(chunk)
