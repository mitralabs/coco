# %% [markdown]
# # Use append_audio()

# %%
# As imported module
from append_audio import append_session_audio

# Process all sessions
processed = append_session_audio(
    base_dir="../_data/audio",
    output_dir="../_data/audio/all_session_test",
    delete_source=False
)
# Out:
# Processing session_23
# ['audio_23_1.wav', 'audio_23_2.wav', 'audio_23_3.wav', 'audio_23_4.wav', 'audio_23_5.wav']
# Created: ../_data/audio/all_session_test/session_23.wav
#
# Processing session_25
# ['audio_25_1.wav', 'audio_25_2.wav', 'audio_25_3.wav', 'audio_25_4.wav', 'audio_25_5.wav', 'audio_25_6.wav', 'audio_25_7.wav', 'audio_25_8.wav', 'audio_25_9.wav', 'audio_25_10.wav', 'audio_25_11.wav', 'audio_25_12.wav', 'audio_25_13.wav', 'audio_25_14.wav', 'audio_25_15.wav', 'audio_25_16.wav', 'audio_25_17.wav', 'audio_25_18.wav', 'audio_25_19.wav', 'audio_25_20.wav', 'audio_25_21.wav', 'audio_25_22.wav', 'audio_25_23.wav', 'audio_25_24.wav', 'audio_25_25.wav', 'audio_25_26.wav', 'audio_25_27.wav', 'audio_25_28.wav', 'audio_25_29.wav', 'audio_25_30.wav', 'audio_25_31.wav', 'audio_25_32.wav', 'audio_25_33.wav', 'audio_25_34.wav', 'audio_25_35.wav', 'audio_25_36.wav', 'audio_25_37.wav', 'audio_25_38.wav', 'audio_25_39.wav', 'audio_25_40.wav', 'audio_25_41.wav', 'audio_25_42.wav', 'audio_25_43.wav', 'audio_25_44.wav', 'audio_25_45.wav', 'audio_25_46.wav', 'audio_25_47.wav', 'audio_25_48.wav', 'audio_25_49.wav', 'audio_25_50.wav', 'audio_25_51.wav', 'audio_25_52.wav', 'audio_25_53.wav', 'audio_25_54.wav', 'audio_25_55.wav', 'audio_25_56.wav', 'audio_25_57.wav', 'audio_25_58.wav', 'audio_25_59.wav', 'audio_25_60.wav', 'audio_25_61.wav', 'audio_25_62.wav', 'audio_25_63.wav', 'audio_25_64.wav', 'audio_25_65.wav', 'audio_25_66.wav', 'audio_25_67.wav', 'audio_25_68.wav', 'audio_25_69.wav', 'audio_25_70.wav', 'audio_25_71.wav', 'audio_25_72.wav', 'audio_25_73.wav', 'audio_25_74.wav', 'audio_25_75.wav', 'audio_25_76.wav', 'audio_25_77.wav', 'audio_25_78.wav', 'audio_25_79.wav', 'audio_25_80.wav', 'audio_25_81.wav', 'audio_25_82.wav', 'audio_25_83.wav', 'audio_25_84.wav', 'audio_25_85.wav', 'audio_25_86.wav', 'audio_25_87.wav', 'audio_25_88.wav', 'audio_25_89.wav', 'audio_25_90.wav', 'audio_25_91.wav', 'audio_25_92.wav', 'audio_25_93.wav', 'audio_25_94.wav', 'audio_25_95.wav', 'audio_25_96.wav', 'audio_25_97.wav', 'audio_25_98.wav', 'audio_25_99.wav', 'audio_25_100.wav', 'audio_25_101.wav', 'audio_25_102.wav', 'audio_25_103.wav', 'audio_25_104.wav', 'audio_25_105.wav', 'audio_25_106.wav', 'audio_25_107.wav', 'audio_25_108.wav', 'audio_25_109.wav', 'audio_25_110.wav', 'audio_25_111.wav', 'audio_25_112.wav', 'audio_25_113.wav', 'audio_25_114.wav', 'audio_25_115.wav', 'audio_25_116.wav', 'audio_25_117.wav', 'audio_25_118.wav', 'audio_25_119.wav', 'audio_25_120.wav', 'audio_25_121.wav', 'audio_25_122.wav', 'audio_25_123.wav', 'audio_25_124.wav', 'audio_25_125.wav', 'audio_25_126.wav', 'audio_25_127.wav', 'audio_25_128.wav', 'audio_25_129.wav', 'audio_25_130.wav', 'audio_25_131.wav', 'audio_25_132.wav', 'audio_25_133.wav', 'audio_25_134.wav', 'audio_25_135.wav', 'audio_25_136.wav', 'audio_25_137.wav', 'audio_25_138.wav', 'audio_25_139.wav', 'audio_25_140.wav', 'audio_25_141.wav', 'audio_25_142.wav', 'audio_25_143.wav', 'audio_25_144.wav', 'audio_25_145.wav', 'audio_25_146.wav', 'audio_25_147.wav', 'audio_25_148.wav', 'audio_25_149.wav', 'audio_25_150.wav', 'audio_25_151.wav', 'audio_25_152.wav', 'audio_25_153.wav', 'audio_25_154.wav', 'audio_25_155.wav', 'audio_25_156.wav', 'audio_25_157.wav', 'audio_25_158.wav', 'audio_25_159.wav', 'audio_25_160.wav', 'audio_25_161.wav', 'audio_25_162.wav', 'audio_25_163.wav', 'audio_25_164.wav', 'audio_25_165.wav', 'audio_25_166.wav', 'audio_25_167.wav', 'audio_25_168.wav', 'audio_25_169.wav', 'audio_25_170.wav', 'audio_25_171.wav', 'audio_25_172.wav', 'audio_25_173.wav', 'audio_25_174.wav', 'audio_25_175.wav', 'audio_25_176.wav', 'audio_25_177.wav', 'audio_25_178.wav', 'audio_25_179.wav', 'audio_25_180.wav', 'audio_25_181.wav', 'audio_25_182.wav', 'audio_25_183.wav', 'audio_25_184.wav', 'audio_25_185.wav', 'audio_25_186.wav', 'audio_25_187.wav', 'audio_25_188.wav', 'audio_25_189.wav', 'audio_25_190.wav', 'audio_25_191.wav', 'audio_25_192.wav', 'audio_25_193.wav', 'audio_25_194.wav', 'audio_25_195.wav', 'audio_25_196.wav', 'audio_25_197.wav', 'audio_25_198.wav', 'audio_25_199.wav', 'audio_25_200.wav', 'audio_25_201.wav', 'audio_25_202.wav', 'audio_25_203.wav', 'audio_25_204.wav', 'audio_25_205.wav', 'audio_ ...
# Created: ../_data/audio/all_session_test/session_25.wav
#
# Processing complete!

# %% [markdown]
# ---

# %% [markdown]
# # Removing Silence

# %%
# !pip install webrtcvad
# Out:
# Collecting webrtcvad
#   Downloading webrtcvad-2.0.10.tar.gz (66 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: webrtcvad
#   Building wheel for webrtcvad (pyproject.toml) ... done
#   Created wheel for webrtcvad: filename=webrtcvad-2.0.10-cp311-cp311-macosx_11_0_arm64.whl size=26149 sha256=cab1d9de939e197b13956a2172ffd6a4f153f8a7db7300862ac8f94ed8a14c09
#   Stored in directory: /Users/tillmann/Library/Caches/pip/wheels/94/65/3f/292d0b656be33d1c801831201c74b5f68f41a2ae465ff2ee2f
# Successfully built webrtcvad
# Installing collected packages: webrtcvad
# Successfully installed webrtcvad-2.0.10

# %%
import webrtcvad
import wave

vad = webrtcvad.Vad(1)

def process_audio(audio_file,aggressiveness =1, frame_duration=30):
    vad = webrtcvad.Vad(aggressiveness)  # 0 to 3, while 3 is the most aggressive
    
    with wave.open(audio_file, 'rb') as wf:
        sample_rate = wf.getframerate()
        
        # Calculate frame size (must be 10, 20, or 30 ms for WebRTC VAD)
        if frame_duration not in [10, 20, 30]:
            frame_duration = 30
            
        frame_size = int(sample_rate * frame_duration / 1000)
        
        segments = []

        while True:
            frame = wf.readframes(frame_size)
            if not frame:
                break
                
            # Ensure we have enough samples for a complete frame
            if len(frame) < frame_size * 2:  # *2 because 16-bit samples
                break
                
            try:
                is_speech = vad.is_speech(frame, sample_rate)
                segments.append({
                    'start': wf.tell() / sample_rate - frame_duration / 1000,
                    'end': wf.tell() / sample_rate,
                    'is_speech': is_speech
                })
            except Exception as e:
                print(f"Error processing frame: {e}")
                continue

        return segments 

# Process the audio file
segments = process_audio("../_data/audio/all_sessions/session_23.wav")

# Print the segments
for segment in segments:
    print(segment)
# Out:
# {'start': 0.0, 'end': 0.03, 'is_speech': True}
# {'start': 0.03, 'end': 0.06, 'is_speech': True}
# {'start': 0.06, 'end': 0.09, 'is_speech': True}
# {'start': 0.09, 'end': 0.12, 'is_speech': True}
# {'start': 0.12, 'end': 0.15, 'is_speech': True}
# {'start': 0.15, 'end': 0.18, 'is_speech': False}
# {'start': 0.18, 'end': 0.21, 'is_speech': False}
# {'start': 0.21, 'end': 0.24, 'is_speech': False}
# {'start': 0.24000000000000002, 'end': 0.27, 'is_speech': False}
# {'start': 0.27, 'end': 0.3, 'is_speech': False}
# {'start': 0.30000000000000004, 'end': 0.33, 'is_speech': False}
# {'start': 0.32999999999999996, 'end': 0.36, 'is_speech': False}
# {'start': 0.36, 'end': 0.39, 'is_speech': False}
# {'start': 0.39, 'end': 0.42, 'is_speech': False}
# {'start': 0.42000000000000004, 'end': 0.45, 'is_speech': False}
# {'start': 0.44999999999999996, 'end': 0.48, 'is_speech': False}
# {'start': 0.48, 'end': 0.51, 'is_speech': False}
# {'start': 0.51, 'end': 0.54, 'is_speech': False}
# {'start': 0.5399999999999999, 'end': 0.57, 'is_speech': False}
# {'start': 0.57, 'end': 0.6, 'is_speech': False}
# {'start': 0.6, 'end': 0.63, 'is_speech': False}
# {'start': 0.63, 'end': 0.66, 'is_speech': False}
# {'start': 0.6599999999999999, 'end': 0.69, 'is_speech': False}
# {'start': 0.69, 'end': 0.72, 'is_speech': False}
# {'start': 0.72, 'end': 0.75, 'is_speech': False}
# {'start': 0.75, 'end': 0.78, 'is_speech': False}
# {'start': 0.78, 'end': 0.81, 'is_speech': False}
# {'start': 0.8099999999999999, 'end': 0.84, 'is_speech': False}
# {'start': 0.84, 'end': 0.87, 'is_speech': False}
# {'start': 0.87, 'end': 0.9, 'is_speech': False}
# {'start': 0.9, 'end': 0.93, 'is_speech': False}
# {'start': 0.9299999999999999, 'end': 0.96, 'is_speech': False}
# {'start': 0.96, 'end': 0.99, 'is_speech': False}
# {'start': 0.99, 'end': 1.02, 'is_speech': False}
# {'start': 1.02, 'end': 1.05, 'is_speech': False}
# {'start': 1.05, 'end': 1.08, 'is_speech': False}
# {'start': 1.08, 'end': 1.11, 'is_speech': False}
# {'start': 1.1099999999999999, 'end': 1.14, 'is_speech': False}
# {'start': 1.14, 'end': 1.17, 'is_speech': False}
# {'start': 1.17, 'end': 1.2, 'is_speech': False}
# {'start': 1.2, 'end': 1.23, 'is_speech': False}
# {'start': 1.23, 'end': 1.26, 'is_speech': False}
# {'start': 1.26, 'end': 1.29, 'is_speech': False}
# {'start': 1.29, 'end': 1.32, 'is_speech': False}
# {'start': 1.32, 'end': 1.35, 'is_speech': False}
# {'start': 1.3499999999999999, 'end': 1.38, 'is_speech': False}
# {'start': 1.38, 'end': 1.41, 'is_speech': False}
# {'start': 1.41, 'end': 1.44, 'is_speech': False}
# {'start': 1.44, 'end': 1.47, 'is_speech': False}
# {'start': 1.47, 'end': 1.5, 'is_speech': False}
# {'start': 1.5, 'end': 1.53, 'is_speech': False}
# {'start': 1.53, 'end': 1.56, 'is_speech': False}
# {'start': 1.56, 'end': 1.59, 'is_speech': False}
# {'start': 1.59, 'end': 1.62, 'is_speech': True}
# {'start': 1.6199999999999999, 'end': 1.65, 'is_speech': True}
# {'start': 1.65, 'end': 1.68, 'is_speech': True}
# {'start': 1.68, 'end': 1.71, 'is_speech': True}
# {'start': 1.71, 'end': 1.74, 'is_speech': True}
# {'start': 1.74, 'end': 1.77, 'is_speech': False}
# {'start': 1.77, 'end': 1.8, 'is_speech': False}
# {'start': 1.8, 'end': 1.83, 'is_speech': False}
# {'start': 1.83, 'end': 1.86, 'is_speech': False}
# {'start': 1.8599999999999999, 'end': 1.89, 'is_speech': False}
# {'start': 1.89, 'end': 1.92, 'is_speech': False}
# {'start': 1.92, 'end': 1.95, 'is_speech': False}
# {'start': 1.95, 'end': 1.98, 'is_speech': False}
# {'start': 1.9799999999999998, 'end': 2.01, 'is_speech': False}
# {'start': 2.0100000000000002, 'end': 2.04, 'is_speech': False}
# {'start': 2.04, 'end': 2.07, 'is_speech': False}
# {'start': 2.0700000000000003, 'end': 2.1, 'is_speech': False}
# {'start': 2.1, 'end': 2.13, 'is_speech': False}
# {'start': 2.1300000000000003, 'end': 2.16, 'is_speech': False}
# {'start': 2.16, 'end': 2.19, 'is_speech': False}
# {'start': 2.1900000000000004, 'end': 2.22, 'is_speech': False}
# {'start': 2.22, 'end': 2.25, 'is_speech': False}
# {'start': 2.25, 'end': 2.28, 'is_speech': False}
# {'start': 2.2800000000000002, 'end': 2.31, 'is_speech': False}
# {'start': 2.31, 'end': 2.34, 'is_speech': False}
# {'start': 2.3400000000000003, 'end': 2.37, 'is_speech': False}
# {'start': 2.37, 'end': 2.4, 'is_speech': False}
# {'start': 2.4000000000000004, 'end': 2.43, 'is_speech': False}
# {'start': 2.43, 'end': 2.46, 'is_speech': False}
# {'start': 2.4600000000000004, 'end': 2.49, 'is_speech': False}
# {'start': 2.49, 'end': 2.52, 'is_speech': False}
# {'start': 2.52, 'end': 2.55, 'is_speech': False}
# {'start': 2.5500000000000003, 'end': 2.58, 'is_speech': False}
# {'start': 2.58, 'end': 2.61, 'is_speech': False}
# {'start': 2.6100000000000003, 'end': 2.64, 'is_speech': False}
# {'start': 2.64, 'end': 2.67, 'is_speech': False}
# {'start': 2.6700000000000004, 'end': 2.7, 'is_speech': False}
# {'start': 2.7, 'end': 2.73, 'is_speech': False}
# {'start': 2.73, 'end': 2.76, 'is_speech': False}
# {'start': 2.7600000000000002, 'end': 2.79, 'is_speech': False}
# {'start': 2.79, 'end': 2.82, 'is_speech': True}
# {'start': 2.8200000000000003, 'end': 2.85, 'is_speech': True}
# {'start': 2.85, 'end': 2.88, 'is_speech': True}
# {'start': 2.8800000000000003, 'end': 2.91, 'is_speech': True}
# {'start': 2.91, 'end': 2.94, 'is_speech': True}
# {'start': 2.9400000000000004, 'end': 2.97, 'is_speech': True}
# {'start': 2.97, 'end': 3.0, 'is_speech': True}
# {'start': 3.0, 'end': 3.03, 'is_speech': True}
# {'start': 3.0300000000000002, 'end': 3.06, 'is_speech': True}
# {'start': 3.06, 'end': 3.09, 'is_speech': False}
# {'start': 3.0900000000000003, 'end': 3.12, 'is_speech': False}
# {'start': 3.12, 'end': 3.15, 'is_speech': False}
# {'start': 3.1500000000000004, 'end': 3.18, 'is_speech': False}
# {'start': 3.18, 'end': 3.21, 'is_speech': False}
# {'start': 3.2100000000000004, 'end': 3.24, 'is_speech': False}
# {'start': 3.24, 'end': 3.27, 'is_speech': False}
# {'start': 3.27, 'end': 3.3, 'is_speech': False}
# {'start': 3.3000000000000003, 'end': 3.33, 'is_speech': False}
# {'start': 3.33, 'end': 3.36, 'is_speech': False}
# {'start': 3.3600000000000003, 'end': 3.39, 'is_speech': False}
# {'start': 3.39, 'end': 3.42, 'is_speech': False}
# {'start': 3.4200000000000004, 'end': 3.45, 'is_speech': False}
# {'start': 3.45, 'end': 3.48, 'is_speech': False}
# {'start': 3.48, 'end': 3.51, 'is_speech': False}
# {'start': 3.5100000000000002, 'end': 3.54, 'is_speech': False}
# {'start': 3.54, 'end': 3.57, 'is_speech': False}
# {'start': 3.5700000000000003, 'end': 3.6, 'is_speech': False}
# {'start': 3.6, 'end': 3.63, 'is_speech': False}
# {'start': 3.6300000000000003, 'end': 3.66, 'is_speech': False}
# {'start': 3.66, 'end': 3.69, 'is_speech': False}
# {'start': 3.6900000000000004, 'end': 3.72, 'is_speech': False}
# {'start': 3.72, 'end': 3.75, 'is_speech': False}
# {'start': 3.75, 'end': 3.78, 'is_speech': False}
# {'start': 3.7800000000000002, 'end': 3.81, 'is_speech': False}
# {'start': 3.81, 'end': 3.84, 'is_speech': False}
# {'start': 3.8400000000000003, 'end': 3.87, 'is_speech': False}
# {'start': 3.87, 'end': 3.9, 'is_speech': True}
# {'start': 3.9000000000000004, 'end': 3.93, 'is_speech': True}
# {'start': 3.93, 'end': 3.96, 'is_speech': True}
# {'start': 3.9600000000000004, 'end': 3.99, 'is_speech': True}
# {'start': 3.9899999999999998, 'end': 4.02, 'is_speech': True}
# {'start': 4.02, 'end': 4.05, 'is_speech': True}
# {'start': 4.05, 'end': 4.08, 'is_speech': True}
# {'start': 4.08, 'end': 4.11, 'is_speech': True}
# {'start': 4.109999999999999, 'end': 4.14, 'is_speech': True}
# {'start': 4.14, 'end': 4.17, 'is_speech': True}
# {'start': 4.17, 'end': 4.2, 'is_speech': True}
# {'start': 4.2, 'end': 4.23, 'is_speech': True}
# {'start': 4.2299999999999995, 'end': 4.26, 'is_speech': False}
# {'start': 4.26, 'end': 4.29, 'is_speech': False}
# {'start': 4.29, 'end': 4.32, 'is_speech': True}
# {'start': 4.319999999999999, 'end': 4.35, 'is_speech': True}
# {'start': 4.35, 'end': 4.38, 'is_speech': True}
# {'start': 4.38, 'end': 4.41, 'is_speech': True}
# {'start': 4.41, 'end': 4.44, 'is_speech': False}
# {'start': 4.4399999999999995, 'end': 4.47, 'is_speech': False}
# {'start': 4.47, 'end': 4.5, 'is_speech': True}
# {'start': 4.5, 'end': 4.53, 'is_speech': True}
# {'start': 4.529999999999999, 'end': 4.56, 'is_speech': True}
# {'start': 4.56, 'end': 4.59, 'is_speech': True}
# {'start': 4.59, 'end': 4.62, 'is_speech': True}
# {'start': 4.62, 'end': 4.65, 'is_speech': True}
# {'start': 4.6499999999999995, 'end': 4.68, 'is_speech': False}
# {'start': 4.68, 'end': 4.71, 'is_speech': False}
# {'start': 4.71, 'end': 4.74, 'is_speech': False}
# {'start': 4.739999999999999, 'end': 4.77, 'is_speech': False}
# {'start': 4.77, 'end': 4.8, 'is_speech': True}
# {'start': 4.8, 'end': 4.83, 'is_speech': True}
# {'start': 4.83, 'end': 4.86, 'is_speech': True}
# {'start': 4.859999999999999, 'end': 4.89, 'is_speech': True}
# {'start': 4.89, 'end': 4.92, 'is_speech': True}
# {'start': 4.92, 'end': 4.95, 'is_speech': True}
# {'start': 4.95, 'end': 4.98, 'is_speech': True}
# {'start': 4.9799999999999995, 'end': 5.01, 'is_speech': True}
# {'start': 5.01, 'end': 5.04, 'is_speech': False}
# {'start': 5.04, 'end': 5.07, 'is_speech': False}
# {'start': 5.069999999999999, 'end': 5.1, 'is_speech': False}
# {'start': 5.1, 'end': 5.13, 'is_speech': False}
# {'start': 5.13, 'end': 5.16, 'is_speech': False}
# {'start': 5.16, 'end': 5.19, 'is_speech': False}
# {'start': 5.1899999999999995, 'end': 5.22, 'is_speech': False}
# {'start': 5.22, 'end': 5.25, 'is_speech': False}
# {'start': 5.25, 'end': 5.28, 'is_speech': False}
# {'start': 5.279999999999999, 'end': 5.31, 'is_speech': False}
# {'start': 5.31, 'end': 5.34, 'is_speech': False}
# {'start': 5.34, 'end': 5.37, 'is_speech': False}
# {'start': 5.37, 'end': 5.4, 'is_speech': True}
# {'start': 5.3999999999999995, 'end': 5.43, 'is_speech': True}
# {'start': 5.43, 'end': 5.46, 'is_speech': True}
# {'start': 5.46, 'end': 5.49, 'is_speech': True}
# {'start': 5.489999999999999, 'end': 5.52, 'is_speech': True}
# {'start': 5.52, 'end': 5.55, 'is_speech': True}
# {'start': 5.55, 'end': 5.58, 'is_speech': True}
# {'start': 5.58, 'end': 5.61, 'is_speech': True}
# {'start': 5.609999999999999, 'end': 5.64, 'is_speech': True}
# {'start': 5.64, 'end': 5.67, 'is_speech': True}
# {'start': 5.67, 'end': 5.7, 'is_speech': True}
# {'start': 5.7, 'end': 5.73, 'is_speech': False}
# {'start': 5.7299999999999995, 'end': 5.76, 'is_speech': False}
# {'start': 5.76, 'end': 5.79, 'is_speech': False}
# {'start': 5.79, 'end': 5.82, 'is_speech': False}
# {'start': 5.819999999999999, 'end': 5.85, 'is_speech': False}
# {'start': 5.85, 'end': 5.88, 'is_speech': False}
# {'start': 5.88, 'end': 5.91, 'is_speech': False}
# {'start': 5.91, 'end': 5.94, 'is_speech': False}
# {'start': 5.9399999999999995, 'end': 5.97, 'is_speech': False}
# {'start': 5.97, 'end': 6.0, 'is_speech': False}
# {'start': 6.0, 'end': 6.03, 'is_speech': False}
# {'start': 6.029999999999999, 'end': 6.06, 'is_speech': False}
# {'start': 6.06, 'end': 6.09, 'is_speech': False}
# {'start': 6.09, 'end': 6.12, 'is_speech': False}
# {'start': 6.12, 'end': 6.15, 'is_speech': False}
# {'start': 6.1499999999999995, 'end': 6.18, 'is_speech': False}
# {'start': 6.18, 'end': 6.21, 'is_speech': False}
# {'start': 6.21, 'end': 6.24, 'is_speech': False}
# {'start': 6.239999999999999, 'end': 6.27, 'is_speech': False}
# {'start': 6.27, 'end': 6.3, 'is_speech': False}
# {'start': 6.3, 'end': 6.33, 'is_speech': False}
# {'start': 6.33, 'end': 6.36, 'is_speech': False}
# {'start': 6.359999999999999, 'end': 6.39, 'is_speech': False}
# {'start': 6.39, 'end': 6.42, 'is_speech': False}
# {'start': 6.42, 'end': 6.45, 'is_speech': False}
# {'start': 6.45, 'end': 6.48, 'is_speech': False}
# {'start': 6.4799999999999995, 'end': 6.51, 'is_speech': False}
# {'start': 6.51, 'end': 6.54, 'is_speech': False}
# {'start': 6.54, 'end': 6.57, 'is_speech': False}
# {'start': 6.569999999999999, 'end': 6.6, 'is_speech': False}
# {'start': 6.6, 'end': 6.63, 'is_speech': False}
# {'start': 6.63, 'end': 6.66, 'is_speech': False}
# {'start': 6.66, 'end': 6.69, 'is_speech': False}
# {'start': 6.6899999999999995, 'end': 6.72, 'is_speech': False}
# {'start': 6.72, 'end': 6.75, 'is_speech': False}
# {'start': 6.75, 'end': 6.78, 'is_speech': False}
# {'start': 6.779999999999999, 'end': 6.81, 'is_speech': False}
# {'start': 6.81, 'end': 6.84, 'is_speech': False}
# {'start': 6.84, 'end': 6.87, 'is_speech': False}
# {'start': 6.87, 'end': 6.9, 'is_speech': False}
# {'start': 6.8999999999999995, 'end': 6.93, 'is_speech': False}
# {'start': 6.93, 'end': 6.96, 'is_speech': False}
# {'start': 6.96, 'end': 6.99, 'is_speech': False}
# {'start': 6.989999999999999, 'end': 7.02, 'is_speech': False}
# {'start': 7.02, 'end': 7.05, 'is_speech': False}
# {'start': 7.05, 'end': 7.08, 'is_speech': False}
# {'start': 7.08, 'end': 7.11, 'is_speech': True}
# {'start': 7.109999999999999, 'end': 7.14, 'is_speech': True}
# {'start': 7.14, 'end': 7.17, 'is_speech': True}
# {'start': 7.17, 'end': 7.2, 'is_speech': True}
# {'start': 7.2, 'end': 7.23, 'is_speech': False}
# {'start': 7.2299999999999995, 'end': 7.26, 'is_speech': False}
# {'start': 7.26, 'end': 7.29, 'is_speech': False}
# {'start': 7.29, 'end': 7.32, 'is_speech': False}
# {'start': 7.319999999999999, 'end': 7.35, 'is_speech': False}
# {'start': 7.35, 'end': 7.38, 'is_speech': False}
# {'start': 7.38, 'end': 7.41, 'is_speech': False}
# {'start': 7.41, 'end': 7.44, 'is_speech': False}
# {'start': 7.4399999999999995, 'end': 7.47, 'is_speech': False}
# {'start': 7.47, 'end': 7.5, 'is_speech': False}
# {'start': 7.5, 'end': 7.53, 'is_speech': False}
# {'start': 7.529999999999999, 'end': 7.56, 'is_speech': False}
# {'start': 7.56, 'end': 7.59, 'is_speech': False}
# {'start': 7.59, 'end': 7.62, 'is_speech': False}
# {'start': 7.62, 'end': 7.65, 'is_speech': False}
# {'start': 7.6499999999999995, 'end': 7.68, 'is_speech': False}
# {'start': 7.68, 'end': 7.71, 'is_speech': False}
# {'start': 7.71, 'end': 7.74, 'is_speech': False}
# {'start': 7.739999999999999, 'end': 7.77, 'is_speech': False}
# {'start': 7.77, 'end': 7.8, 'is_speech': False}
# {'start': 7.8, 'end': 7.83, 'is_speech': False}
# {'start': 7.83, 'end': 7.86, 'is_speech': False}
# {'start': 7.859999999999999, 'end': 7.89, 'is_speech': False}
# {'start': 7.89, 'end': 7.92, 'is_speech': False}
# {'start': 7.92, 'end': 7.95, 'is_speech': False}
# {'start': 7.95, 'end': 7.98, 'is_speech': False}
# {'start': 7.9799999999999995, 'end': 8.01, 'is_speech': False}
# {'start': 8.01, 'end': 8.04, 'is_speech': False}
# {'start': 8.040000000000001, 'end': 8.07, 'is_speech': False}
# {'start': 8.07, 'end': 8.1, 'is_speech': False}
# {'start': 8.100000000000001, 'end': 8.13, 'is_speech': False}
# {'start': 8.13, 'end': 8.16, 'is_speech': False}
# {'start': 8.16, 'end': 8.19, 'is_speech': False}
# {'start': 8.190000000000001, 'end': 8.22, 'is_speech': False}
# {'start': 8.22, 'end': 8.25, 'is_speech': False}
# {'start': 8.25, 'end': 8.28, 'is_speech': False}
# {'start': 8.280000000000001, 'end': 8.31, 'is_speech': False}
# {'start': 8.31, 'end': 8.34, 'is_speech': False}
# {'start': 8.34, 'end': 8.37, 'is_speech': False}
# {'start': 8.370000000000001, 'end': 8.4, 'is_speech': False}
# {'start': 8.4, 'end': 8.43, 'is_speech': False}
# {'start': 8.430000000000001, 'end': 8.46, 'is_speech': False}
# {'start': 8.46, 'end': 8.49, 'is_speech': False}
# {'start': 8.49, 'end': 8.52, 'is_speech': False}
# {'start': 8.520000000000001, 'end': 8.55, 'is_speech': False}
# {'start': 8.55, 'end': 8.58, 'is_speech': False}
# {'start': 8.58, 'end': 8.61, 'is_speech': False}
# {'start': 8.610000000000001, 'end': 8.64, 'is_speech': False}
# {'start': 8.64, 'end': 8.67, 'is_speech': False}
# {'start': 8.67, 'end': 8.7, 'is_speech': False}
# {'start': 8.700000000000001, 'end': 8.73, 'is_speech': False}
# {'start': 8.73, 'end': 8.76, 'is_speech': False}
# {'start': 8.76, 'end': 8.79, 'is_speech': False}
# {'start': 8.790000000000001, 'end': 8.82, 'is_speech': False}
# {'start': 8.82, 'end': 8.85, 'is_speech': False}
# {'start': 8.850000000000001, 'end': 8.88, 'is_speech': False}
# {'start': 8.88, 'end': 8.91, 'is_speech': False}
# {'start': 8.91, 'end': 8.94, 'is_speech': False}
# {'start': 8.940000000000001, 'end': 8.97, 'is_speech': False}
# {'start': 8.97, 'end': 9.0, 'is_speech': False}
# {'start': 9.0, 'end': 9.03, 'is_speech': False}
# {'start': 9.030000000000001, 'end': 9.06, 'is_speech': False}
# {'start': 9.06, 'end': 9.09, 'is_speech': False}
# {'start': 9.09, 'end': 9.12, 'is_speech': False}
# {'start': 9.120000000000001, 'end': 9.15, 'is_speech': False}
# {'start': 9.15, 'end': 9.18, 'is_speech': False}
# {'start': 9.180000000000001, 'end': 9.21, 'is_speech': False}
# {'start': 9.21, 'end': 9.24, 'is_speech': False}
# {'start': 9.24, 'end': 9.27, 'is_speech': False}
# {'start': 9.270000000000001, 'end': 9.3, 'is_speech': False}
# {'start': 9.3, 'end': 9.33, 'is_speech': False}
# {'start': 9.33, 'end': 9.36, 'is_speech': False}
# {'start': 9.360000000000001, 'end': 9.39, 'is_speech': False}
# {'start': 9.39, 'end': 9.42, 'is_speech': False}
# {'start': 9.42, 'end': 9.45, 'is_speech': False}
# {'start': 9.450000000000001, 'end': 9.48, 'is_speech': False}
# {'start': 9.48, 'end': 9.51, 'is_speech': False}
# {'start': 9.51, 'end': 9.54, 'is_speech': False}
# {'start': 9.540000000000001, 'end': 9.57, 'is_speech': False}
# {'start': 9.57, 'end': 9.6, 'is_speech': False}
# {'start': 9.600000000000001, 'end': 9.63, 'is_speech': False}
# {'start': 9.63, 'end': 9.66, 'is_speech': False}
# {'start': 9.66, 'end': 9.69, 'is_speech': False}
# {'start': 9.690000000000001, 'end': 9.72, 'is_speech': False}
# {'start': 9.72, 'end': 9.75, 'is_speech': False}
# {'start': 9.75, 'end': 9.78, 'is_speech': False}
# {'start': 9.780000000000001, 'end': 9.81, 'is_speech': False}
# {'start': 9.81, 'end': 9.84, 'is_speech': False}
# {'start': 9.84, 'end': 9.87, 'is_speech': False}
# {'start': 9.870000000000001, 'end': 9.9, 'is_speech': False}
# {'start': 9.9, 'end': 9.93, 'is_speech': False}
# {'start': 9.930000000000001, 'end': 9.96, 'is_speech': False}
# {'start': 9.96, 'end': 9.99, 'is_speech': False}
# {'start': 9.99, 'end': 10.02, 'is_speech': False}
# {'start': 10.020000000000001, 'end': 10.05, 'is_speech': False}
# {'start': 10.05, 'end': 10.08, 'is_speech': False}
# {'start': 10.08, 'end': 10.11, 'is_speech': False}
# {'start': 10.110000000000001, 'end': 10.14, 'is_speech': False}
# {'start': 10.14, 'end': 10.17, 'is_speech': False}
# {'start': 10.17, 'end': 10.2, 'is_speech': False}
# {'start': 10.200000000000001, 'end': 10.23, 'is_speech': False}
# {'start': 10.23, 'end': 10.26, 'is_speech': False}
# {'start': 10.26, 'end': 10.29, 'is_speech': False}
# {'start': 10.290000000000001, 'end': 10.32, 'is_speech': False}
# {'start': 10.32, 'end': 10.35, 'is_speech': False}
# {'start': 10.350000000000001, 'end': 10.38, 'is_speech': False}
# {'start': 10.38, 'end': 10.41, 'is_speech': False}
# {'start': 10.41, 'end': 10.44, 'is_speech': False}
# {'start': 10.440000000000001, 'end': 10.47, 'is_speech': False}
# {'start': 10.47, 'end': 10.5, 'is_speech': False}
# {'start': 10.5, 'end': 10.53, 'is_speech': False}
# {'start': 10.530000000000001, 'end': 10.56, 'is_speech': False}
# {'start': 10.56, 'end': 10.59, 'is_speech': False}
# {'start': 10.59, 'end': 10.62, 'is_speech': False}
# {'start': 10.620000000000001, 'end': 10.65, 'is_speech': False}
# {'start': 10.65, 'end': 10.68, 'is_speech': False}
# {'start': 10.680000000000001, 'end': 10.71, 'is_speech': False}
# {'start': 10.71, 'end': 10.74, 'is_speech': False}
# {'start': 10.74, 'end': 10.77, 'is_speech': False}
# {'start': 10.770000000000001, 'end': 10.8, 'is_speech': False}
# {'start': 10.8, 'end': 10.83, 'is_speech': False}
# {'start': 10.83, 'end': 10.86, 'is_speech': False}
# {'start': 10.860000000000001, 'end': 10.89, 'is_speech': False}
# {'start': 10.89, 'end': 10.92, 'is_speech': False}
# {'start': 10.92, 'end': 10.95, 'is_speech': False}
# {'start': 10.950000000000001, 'end': 10.98, 'is_speech': False}
# {'start': 10.98, 'end': 11.01, 'is_speech': False}
# {'start': 11.01, 'end': 11.04, 'is_speech': False}
# {'start': 11.040000000000001, 'end': 11.07, 'is_speech': False}
# {'start': 11.07, 'end': 11.1, 'is_speech': False}
# {'start': 11.100000000000001, 'end': 11.13, 'is_speech': False}
# {'start': 11.13, 'end': 11.16, 'is_speech': False}
# {'start': 11.16, 'end': 11.19, 'is_speech': False}
# {'start': 11.190000000000001, 'end': 11.22, 'is_speech': False}
# {'start': 11.22, 'end': 11.25, 'is_speech': False}
# {'start': 11.25, 'end': 11.28, 'is_speech': False}
# {'start': 11.280000000000001, 'end': 11.31, 'is_speech': False}
# {'start': 11.31, 'end': 11.34, 'is_speech': False}
# {'start': 11.34, 'end': 11.37, 'is_speech': False}
# {'start': 11.370000000000001, 'end': 11.4, 'is_speech': False}
# {'start': 11.4, 'end': 11.43, 'is_speech': False}
# {'start': 11.430000000000001, 'end': 11.46, 'is_speech': False}
# {'start': 11.46, 'end': 11.49, 'is_speech': False}
# {'start': 11.49, 'end': 11.52, 'is_speech': False}
# {'start': 11.520000000000001, 'end': 11.55, 'is_speech': False}
# {'start': 11.55, 'end': 11.58, 'is_speech': False}
# {'start': 11.58, 'end': 11.61, 'is_speech': False}
# {'start': 11.610000000000001, 'end': 11.64, 'is_speech': False}
# {'start': 11.64, 'end': 11.67, 'is_speech': False}
# {'start': 11.67, 'end': 11.7, 'is_speech': False}
# {'start': 11.700000000000001, 'end': 11.73, 'is_speech': False}
# {'start': 11.73, 'end': 11.76, 'is_speech': False}
# {'start': 11.76, 'end': 11.79, 'is_speech': False}
# {'start': 11.790000000000001, 'end': 11.82, 'is_speech': False}
# {'start': 11.82, 'end': 11.85, 'is_speech': False}
# {'start': 11.850000000000001, 'end': 11.88, 'is_speech': False}
# {'start': 11.88, 'end': 11.91, 'is_speech': False}
# {'start': 11.91, 'end': 11.94, 'is_speech': False}
# {'start': 11.940000000000001, 'end': 11.97, 'is_speech': False}
# {'start': 11.97, 'end': 12.0, 'is_speech': False}
# {'start': 12.0, 'end': 12.03, 'is_speech': False}
# {'start': 12.030000000000001, 'end': 12.06, 'is_speech': False}
# {'start': 12.06, 'end': 12.09, 'is_speech': False}
# {'start': 12.09, 'end': 12.12, 'is_speech': False}
# {'start': 12.120000000000001, 'end': 12.15, 'is_speech': False}
# {'start': 12.15, 'end': 12.18, 'is_speech': False}
# {'start': 12.180000000000001, 'end': 12.21, 'is_speech': False}
# {'start': 12.21, 'end': 12.24, 'is_speech': False}
# {'start': 12.24, 'end': 12.27, 'is_speech': False}
# {'start': 12.270000000000001, 'end': 12.3, 'is_speech': False}
# {'start': 12.3, 'end': 12.33, 'is_speech': False}
# {'start': 12.33, 'end': 12.36, 'is_speech': False}
# {'start': 12.360000000000001, 'end': 12.39, 'is_speech': False}
# {'start': 12.39, 'end': 12.42, 'is_speech': False}
# {'start': 12.42, 'end': 12.45, 'is_speech': False}
# {'start': 12.450000000000001, 'end': 12.48, 'is_speech': False}
# {'start': 12.48, 'end': 12.51, 'is_speech': False}
# {'start': 12.51, 'end': 12.54, 'is_speech': False}
# {'start': 12.540000000000001, 'end': 12.57, 'is_speech': False}
# {'start': 12.57, 'end': 12.6, 'is_speech': False}
# {'start': 12.600000000000001, 'end': 12.63, 'is_speech': False}
# {'start': 12.63, 'end': 12.66, 'is_speech': False}
# {'start': 12.66, 'end': 12.69, 'is_speech': False}
# {'start': 12.690000000000001, 'end': 12.72, 'is_speech': False}
# {'start': 12.72, 'end': 12.75, 'is_speech': False}
# {'start': 12.75, 'end': 12.78, 'is_speech': False}
# {'start': 12.780000000000001, 'end': 12.81, 'is_speech': False}
# {'start': 12.81, 'end': 12.84, 'is_speech': False}
# {'start': 12.84, 'end': 12.87, 'is_speech': False}
# {'start': 12.870000000000001, 'end': 12.9, 'is_speech': False}
# {'start': 12.9, 'end': 12.93, 'is_speech': False}
# {'start': 12.930000000000001, 'end': 12.96, 'is_speech': False}
# {'start': 12.96, 'end': 12.99, 'is_speech': False}
# {'start': 12.99, 'end': 13.02, 'is_speech': False}
# {'start': 13.020000000000001, 'end': 13.05, 'is_speech': False}
# {'start': 13.05, 'end': 13.08, 'is_speech': False}
# {'start': 13.08, 'end': 13.11, 'is_speech': False}
# {'start': 13.110000000000001, 'end': 13.14, 'is_speech': False}
# {'start': 13.14, 'end': 13.17, 'is_speech': False}
# {'start': 13.17, 'end': 13.2, 'is_speech': False}
# {'start': 13.200000000000001, 'end': 13.23, 'is_speech': False}
# {'start': 13.23, 'end': 13.26, 'is_speech': False}
# {'start': 13.26, 'end': 13.29, 'is_speech': False}
# {'start': 13.290000000000001, 'end': 13.32, 'is_speech': False}
# {'start': 13.32, 'end': 13.35, 'is_speech': False}
# {'start': 13.350000000000001, 'end': 13.38, 'is_speech': False}
# {'start': 13.38, 'end': 13.41, 'is_speech': False}
# {'start': 13.41, 'end': 13.44, 'is_speech': False}
# {'start': 13.440000000000001, 'end': 13.47, 'is_speech': False}
# {'start': 13.47, 'end': 13.5, 'is_speech': True}
# {'start': 13.5, 'end': 13.53, 'is_speech': True}
# {'start': 13.530000000000001, 'end': 13.56, 'is_speech': True}
# {'start': 13.56, 'end': 13.59, 'is_speech': True}
# {'start': 13.59, 'end': 13.62, 'is_speech': False}
# {'start': 13.620000000000001, 'end': 13.65, 'is_speech': False}
# {'start': 13.65, 'end': 13.68, 'is_speech': False}
# {'start': 13.680000000000001, 'end': 13.71, 'is_speech': False}
# {'start': 13.71, 'end': 13.74, 'is_speech': False}
# {'start': 13.74, 'end': 13.77, 'is_speech': False}
# {'start': 13.770000000000001, 'end': 13.8, 'is_speech': False}
# {'start': 13.8, 'end': 13.83, 'is_speech': False}
# {'start': 13.83, 'end': 13.86, 'is_speech': False}
# {'start': 13.860000000000001, 'end': 13.89, 'is_speech': False}
# {'start': 13.89, 'end': 13.92, 'is_speech': False}
# {'start': 13.92, 'end': 13.95, 'is_speech': False}
# {'start': 13.950000000000001, 'end': 13.98, 'is_speech': False}
# {'start': 13.98, 'end': 14.01, 'is_speech': False}
# {'start': 14.01, 'end': 14.04, 'is_speech': False}
# {'start': 14.040000000000001, 'end': 14.07, 'is_speech': False}
# {'start': 14.07, 'end': 14.1, 'is_speech': False}
# {'start': 14.100000000000001, 'end': 14.13, 'is_speech': False}
# {'start': 14.13, 'end': 14.16, 'is_speech': False}
# {'start': 14.16, 'end': 14.19, 'is_speech': False}
# {'start': 14.190000000000001, 'end': 14.22, 'is_speech': False}
# {'start': 14.22, 'end': 14.25, 'is_speech': False}
# {'start': 14.25, 'end': 14.28, 'is_speech': False}
# {'start': 14.280000000000001, 'end': 14.31, 'is_speech': False}
# {'start': 14.31, 'end': 14.34, 'is_speech': False}
# {'start': 14.34, 'end': 14.37, 'is_speech': False}
# {'start': 14.370000000000001, 'end': 14.4, 'is_speech': False}
# {'start': 14.4, 'end': 14.43, 'is_speech': False}
# {'start': 14.430000000000001, 'end': 14.46, 'is_speech': False}
# {'start': 14.46, 'end': 14.49, 'is_speech': False}
# {'start': 14.49, 'end': 14.52, 'is_speech': False}
# {'start': 14.520000000000001, 'end': 14.55, 'is_speech': False}
# {'start': 14.55, 'end': 14.58, 'is_speech': False}
# {'start': 14.58, 'end': 14.61, 'is_speech': False}
# {'start': 14.610000000000001, 'end': 14.64, 'is_speech': False}
# {'start': 14.64, 'end': 14.67, 'is_speech': False}
# {'start': 14.67, 'end': 14.7, 'is_speech': False}
# {'start': 14.700000000000001, 'end': 14.73, 'is_speech': False}
# {'start': 14.73, 'end': 14.76, 'is_speech': False}
# {'start': 14.76, 'end': 14.79, 'is_speech': False}
# {'start': 14.790000000000001, 'end': 14.82, 'is_speech': True}
# {'start': 14.82, 'end': 14.85, 'is_speech': True}
# {'start': 14.850000000000001, 'end': 14.88, 'is_speech': True}
# {'start': 14.88, 'end': 14.91, 'is_speech': True}
# {'start': 14.91, 'end': 14.94, 'is_speech': False}
# {'start': 14.940000000000001, 'end': 14.97, 'is_speech': False}
# {'start': 14.97, 'end': 15.0, 'is_speech': False}
# {'start': 15.0, 'end': 15.03, 'is_speech': False}
# {'start': 15.030000000000001, 'end': 15.06, 'is_speech': False}
# {'start': 15.06, 'end': 15.09, 'is_speech': False}
# {'start': 15.09, 'end': 15.12, 'is_speech': False}
# {'start': 15.120000000000001, 'end': 15.15, 'is_speech': False}
# {'start': 15.15, 'end': 15.18, 'is_speech': False}
# {'start': 15.180000000000001, 'end': 15.21, 'is_speech': False}
# {'start': 15.21, 'end': 15.24, 'is_speech': False}
# {'start': 15.24, 'end': 15.27, 'is_speech': False}
# {'start': 15.270000000000001, 'end': 15.3, 'is_speech': False}
# {'start': 15.3, 'end': 15.33, 'is_speech': False}
# {'start': 15.33, 'end': 15.36, 'is_speech': False}
# {'start': 15.360000000000001, 'end': 15.39, 'is_speech': False}
# {'start': 15.39, 'end': 15.42, 'is_speech': False}
# {'start': 15.42, 'end': 15.45, 'is_speech': False}
# {'start': 15.450000000000001, 'end': 15.48, 'is_speech': False}
# {'start': 15.48, 'end': 15.51, 'is_speech': False}
# {'start': 15.51, 'end': 15.54, 'is_speech': False}
# {'start': 15.540000000000001, 'end': 15.57, 'is_speech': False}
# {'start': 15.57, 'end': 15.6, 'is_speech': True}
# {'start': 15.600000000000001, 'end': 15.63, 'is_speech': True}
# {'start': 15.63, 'end': 15.66, 'is_speech': True}
# {'start': 15.66, 'end': 15.69, 'is_speech': True}
# {'start': 15.690000000000001, 'end': 15.72, 'is_speech': True}
# {'start': 15.72, 'end': 15.75, 'is_speech': True}
# {'start': 15.75, 'end': 15.78, 'is_speech': True}
# {'start': 15.780000000000001, 'end': 15.81, 'is_speech': True}
# {'start': 15.81, 'end': 15.84, 'is_speech': True}
# {'start': 15.84, 'end': 15.87, 'is_speech': True}
# {'start': 15.870000000000001, 'end': 15.9, 'is_speech': True}
# {'start': 15.9, 'end': 15.93, 'is_speech': True}
# {'start': 15.930000000000001, 'end': 15.96, 'is_speech': True}
# {'start': 15.96, 'end': 15.99, 'is_speech': True}
# {'start': 15.99, 'end': 16.02, 'is_speech': True}
# {'start': 16.02, 'end': 16.05, 'is_speech': True}
# {'start': 16.049999999999997, 'end': 16.08, 'is_speech': True}
# {'start': 16.08, 'end': 16.11, 'is_speech': True}
# {'start': 16.11, 'end': 16.14, 'is_speech': True}
# {'start': 16.14, 'end': 16.17, 'is_speech': False}
# {'start': 16.169999999999998, 'end': 16.2, 'is_speech': False}
# {'start': 16.2, 'end': 16.23, 'is_speech': False}
# {'start': 16.23, 'end': 16.26, 'is_speech': False}
# {'start': 16.259999999999998, 'end': 16.29, 'is_speech': False}
# {'start': 16.29, 'end': 16.32, 'is_speech': False}
# {'start': 16.32, 'end': 16.35, 'is_speech': False}
# {'start': 16.349999999999998, 'end': 16.38, 'is_speech': False}
# {'start': 16.38, 'end': 16.41, 'is_speech': False}
# {'start': 16.41, 'end': 16.44, 'is_speech': False}
# {'start': 16.439999999999998, 'end': 16.47, 'is_speech': False}
# {'start': 16.47, 'end': 16.5, 'is_speech': False}
# {'start': 16.5, 'end': 16.53, 'is_speech': False}
# {'start': 16.529999999999998, 'end': 16.56, 'is_speech': False}
# {'start': 16.56, 'end': 16.59, 'is_speech': False}
# {'start': 16.59, 'end': 16.62, 'is_speech': False}
# {'start': 16.619999999999997, 'end': 16.65, 'is_speech': False}
# {'start': 16.65, 'end': 16.68, 'is_speech': False}
# {'start': 16.68, 'end': 16.71, 'is_speech': False}
# {'start': 16.709999999999997, 'end': 16.74, 'is_speech': False}
# {'start': 16.74, 'end': 16.77, 'is_speech': False}
# {'start': 16.77, 'end': 16.8, 'is_speech': False}
# {'start': 16.799999999999997, 'end': 16.83, 'is_speech': True}
# {'start': 16.83, 'end': 16.86, 'is_speech': True}
# {'start': 16.86, 'end': 16.89, 'is_speech': True}
# {'start': 16.89, 'end': 16.92, 'is_speech': True}
# {'start': 16.919999999999998, 'end': 16.95, 'is_speech': False}
# {'start': 16.95, 'end': 16.98, 'is_speech': False}
# {'start': 16.98, 'end': 17.01, 'is_speech': False}
# {'start': 17.009999999999998, 'end': 17.04, 'is_speech': False}
# {'start': 17.04, 'end': 17.07, 'is_speech': False}
# {'start': 17.07, 'end': 17.1, 'is_speech': False}
# {'start': 17.099999999999998, 'end': 17.13, 'is_speech': False}
# {'start': 17.13, 'end': 17.16, 'is_speech': True}
# {'start': 17.16, 'end': 17.19, 'is_speech': True}
# {'start': 17.189999999999998, 'end': 17.22, 'is_speech': True}
# {'start': 17.22, 'end': 17.25, 'is_speech': True}
# {'start': 17.25, 'end': 17.28, 'is_speech': True}
# {'start': 17.279999999999998, 'end': 17.31, 'is_speech': True}
# {'start': 17.31, 'end': 17.34, 'is_speech': True}
# {'start': 17.34, 'end': 17.37, 'is_speech': False}
# {'start': 17.369999999999997, 'end': 17.4, 'is_speech': False}
# {'start': 17.4, 'end': 17.43, 'is_speech': False}
# {'start': 17.43, 'end': 17.46, 'is_speech': False}
# {'start': 17.459999999999997, 'end': 17.49, 'is_speech': False}
# {'start': 17.49, 'end': 17.52, 'is_speech': False}
# {'start': 17.52, 'end': 17.55, 'is_speech': False}
# {'start': 17.549999999999997, 'end': 17.58, 'is_speech': True}
# {'start': 17.58, 'end': 17.61, 'is_speech': True}
# {'start': 17.61, 'end': 17.64, 'is_speech': True}
# {'start': 17.64, 'end': 17.67, 'is_speech': True}
# {'start': 17.669999999999998, 'end': 17.7, 'is_speech': True}
# {'start': 17.7, 'end': 17.73, 'is_speech': True}
# {'start': 17.73, 'end': 17.76, 'is_speech': True}
# {'start': 17.759999999999998, 'end': 17.79, 'is_speech': True}
# {'start': 17.79, 'end': 17.82, 'is_speech': False}
# {'start': 17.82, 'end': 17.85, 'is_speech': False}
# {'start': 17.849999999999998, 'end': 17.88, 'is_speech': False}
# {'start': 17.88, 'end': 17.91, 'is_speech': False}
# {'start': 17.91, 'end': 17.94, 'is_speech': False}
# {'start': 17.939999999999998, 'end': 17.97, 'is_speech': False}
# {'start': 17.97, 'end': 18.0, 'is_speech': False}
# {'start': 18.0, 'end': 18.03, 'is_speech': False}
# {'start': 18.029999999999998, 'end': 18.06, 'is_speech': False}
# {'start': 18.06, 'end': 18.09, 'is_speech': False}
# {'start': 18.09, 'end': 18.12, 'is_speech': False}
# {'start': 18.119999999999997, 'end': 18.15, 'is_speech': False}
# {'start': 18.15, 'end': 18.18, 'is_speech': False}
# {'start': 18.18, 'end': 18.21, 'is_speech': False}
# {'start': 18.209999999999997, 'end': 18.24, 'is_speech': False}
# {'start': 18.24, 'end': 18.27, 'is_speech': True}
# {'start': 18.27, 'end': 18.3, 'is_speech': True}
# {'start': 18.299999999999997, 'end': 18.33, 'is_speech': True}
# {'start': 18.33, 'end': 18.36, 'is_speech': True}
# {'start': 18.36, 'end': 18.39, 'is_speech': True}
# {'start': 18.39, 'end': 18.42, 'is_speech': True}
# {'start': 18.419999999999998, 'end': 18.45, 'is_speech': True}
# {'start': 18.45, 'end': 18.48, 'is_speech': True}
# {'start': 18.48, 'end': 18.51, 'is_speech': True}
# {'start': 18.509999999999998, 'end': 18.54, 'is_speech': True}
# {'start': 18.54, 'end': 18.57, 'is_speech': True}
# {'start': 18.57, 'end': 18.6, 'is_speech': False}
# {'start': 18.599999999999998, 'end': 18.63, 'is_speech': False}
# {'start': 18.63, 'end': 18.66, 'is_speech': False}
# {'start': 18.66, 'end': 18.69, 'is_speech': False}
# {'start': 18.689999999999998, 'end': 18.72, 'is_speech': False}
# {'start': 18.72, 'end': 18.75, 'is_speech': False}
# {'start': 18.75, 'end': 18.78, 'is_speech': False}
# {'start': 18.779999999999998, 'end': 18.81, 'is_speech': False}
# {'start': 18.81, 'end': 18.84, 'is_speech': False}
# {'start': 18.84, 'end': 18.87, 'is_speech': False}
# {'start': 18.869999999999997, 'end': 18.9, 'is_speech': False}
# {'start': 18.9, 'end': 18.93, 'is_speech': False}
# {'start': 18.93, 'end': 18.96, 'is_speech': False}
# {'start': 18.959999999999997, 'end': 18.99, 'is_speech': False}
# {'start': 18.99, 'end': 19.02, 'is_speech': False}
# {'start': 19.02, 'end': 19.05, 'is_speech': False}
# {'start': 19.049999999999997, 'end': 19.08, 'is_speech': False}
# {'start': 19.08, 'end': 19.11, 'is_speech': False}
# {'start': 19.11, 'end': 19.14, 'is_speech': False}
# {'start': 19.14, 'end': 19.17, 'is_speech': False}
# {'start': 19.169999999999998, 'end': 19.2, 'is_speech': True}
# {'start': 19.2, 'end': 19.23, 'is_speech': True}
# {'start': 19.23, 'end': 19.26, 'is_speech': True}
# {'start': 19.259999999999998, 'end': 19.29, 'is_speech': True}
# {'start': 19.29, 'end': 19.32, 'is_speech': True}
# {'start': 19.32, 'end': 19.35, 'is_speech': True}
# {'start': 19.349999999999998, 'end': 19.38, 'is_speech': True}
# {'start': 19.38, 'end': 19.41, 'is_speech': True}
# {'start': 19.41, 'end': 19.44, 'is_speech': True}
# {'start': 19.439999999999998, 'end': 19.47, 'is_speech': True}
# {'start': 19.47, 'end': 19.5, 'is_speech': True}
# {'start': 19.5, 'end': 19.53, 'is_speech': True}
# {'start': 19.529999999999998, 'end': 19.56, 'is_speech': True}
# {'start': 19.56, 'end': 19.59, 'is_speech': True}
# {'start': 19.59, 'end': 19.62, 'is_speech': True}
# {'start': 19.619999999999997, 'end': 19.65, 'is_speech': True}
# {'start': 19.65, 'end': 19.68, 'is_speech': True}
# {'start': 19.68, 'end': 19.71, 'is_speech': True}
# {'start': 19.709999999999997, 'end': 19.74, 'is_speech': True}
# {'start': 19.74, 'end': 19.77, 'is_speech': True}
# {'start': 19.77, 'end': 19.8, 'is_speech': True}
# {'start': 19.799999999999997, 'end': 19.83, 'is_speech': True}
# {'start': 19.83, 'end': 19.86, 'is_speech': True}
# {'start': 19.86, 'end': 19.89, 'is_speech': True}
# {'start': 19.89, 'end': 19.92, 'is_speech': False}
# {'start': 19.919999999999998, 'end': 19.95, 'is_speech': False}
# {'start': 19.95, 'end': 19.98, 'is_speech': False}
# {'start': 19.98, 'end': 20.01, 'is_speech': False}
# {'start': 20.009999999999998, 'end': 20.04, 'is_speech': True}
# {'start': 20.04, 'end': 20.07, 'is_speech': True}
# {'start': 20.07, 'end': 20.1, 'is_speech': True}
# {'start': 20.099999999999998, 'end': 20.13, 'is_speech': True}
# {'start': 20.13, 'end': 20.16, 'is_speech': True}
# {'start': 20.16, 'end': 20.19, 'is_speech': True}
# {'start': 20.189999999999998, 'end': 20.22, 'is_speech': True}
# {'start': 20.22, 'end': 20.25, 'is_speech': True}
# {'start': 20.25, 'end': 20.28, 'is_speech': True}
# {'start': 20.279999999999998, 'end': 20.31, 'is_speech': True}
# {'start': 20.31, 'end': 20.34, 'is_speech': True}
# {'start': 20.34, 'end': 20.37, 'is_speech': True}
# {'start': 20.369999999999997, 'end': 20.4, 'is_speech': True}
# {'start': 20.4, 'end': 20.43, 'is_speech': True}
# {'start': 20.43, 'end': 20.46, 'is_speech': True}
# {'start': 20.459999999999997, 'end': 20.49, 'is_speech': True}
# {'start': 20.49, 'end': 20.52, 'is_speech': True}
# {'start': 20.52, 'end': 20.55, 'is_speech': True}
# {'start': 20.549999999999997, 'end': 20.58, 'is_speech': True}
# {'start': 20.58, 'end': 20.61, 'is_speech': True}
# {'start': 20.61, 'end': 20.64, 'is_speech': True}
# {'start': 20.64, 'end': 20.67, 'is_speech': True}
# {'start': 20.669999999999998, 'end': 20.7, 'is_speech': True}
# {'start': 20.7, 'end': 20.73, 'is_speech': True}
# {'start': 20.73, 'end': 20.76, 'is_speech': True}
# {'start': 20.759999999999998, 'end': 20.79, 'is_speech': True}
# {'start': 20.79, 'end': 20.82, 'is_speech': True}
# {'start': 20.82, 'end': 20.85, 'is_speech': True}
# {'start': 20.849999999999998, 'end': 20.88, 'is_speech': True}
# {'start': 20.88, 'end': 20.91, 'is_speech': True}
# {'start': 20.91, 'end': 20.94, 'is_speech': True}
# {'start': 20.939999999999998, 'end': 20.97, 'is_speech': True}
# {'start': 20.97, 'end': 21.0, 'is_speech': True}
# {'start': 21.0, 'end': 21.03, 'is_speech': True}
# {'start': 21.029999999999998, 'end': 21.06, 'is_speech': True}
# {'start': 21.06, 'end': 21.09, 'is_speech': True}
# {'start': 21.09, 'end': 21.12, 'is_speech': True}
# {'start': 21.119999999999997, 'end': 21.15, 'is_speech': True}
# {'start': 21.15, 'end': 21.18, 'is_speech': True}
# {'start': 21.18, 'end': 21.21, 'is_speech': True}
# {'start': 21.209999999999997, 'end': 21.24, 'is_speech': True}
# {'start': 21.24, 'end': 21.27, 'is_speech': True}
# {'start': 21.27, 'end': 21.3, 'is_speech': True}
# {'start': 21.299999999999997, 'end': 21.33, 'is_speech': True}
# {'start': 21.33, 'end': 21.36, 'is_speech': True}
# {'start': 21.36, 'end': 21.39, 'is_speech': True}
# {'start': 21.39, 'end': 21.42, 'is_speech': True}
# {'start': 21.419999999999998, 'end': 21.45, 'is_speech': True}
# {'start': 21.45, 'end': 21.48, 'is_speech': True}
# {'start': 21.48, 'end': 21.51, 'is_speech': True}
# {'start': 21.509999999999998, 'end': 21.54, 'is_speech': True}
# {'start': 21.54, 'end': 21.57, 'is_speech': True}
# {'start': 21.57, 'end': 21.6, 'is_speech': True}
# {'start': 21.599999999999998, 'end': 21.63, 'is_speech': True}
# {'start': 21.63, 'end': 21.66, 'is_speech': True}
# {'start': 21.66, 'end': 21.69, 'is_speech': True}
# {'start': 21.689999999999998, 'end': 21.72, 'is_speech': True}
# {'start': 21.72, 'end': 21.75, 'is_speech': True}
# {'start': 21.75, 'end': 21.78, 'is_speech': True}
# {'start': 21.779999999999998, 'end': 21.81, 'is_speech': True}
# {'start': 21.81, 'end': 21.84, 'is_speech': True}
# {'start': 21.84, 'end': 21.87, 'is_speech': True}
# {'start': 21.869999999999997, 'end': 21.9, 'is_speech': True}
# {'start': 21.9, 'end': 21.93, 'is_speech': True}
# {'start': 21.93, 'end': 21.96, 'is_speech': True}
# {'start': 21.959999999999997, 'end': 21.99, 'is_speech': True}
# {'start': 21.99, 'end': 22.02, 'is_speech': True}
# {'start': 22.02, 'end': 22.05, 'is_speech': True}
# {'start': 22.049999999999997, 'end': 22.08, 'is_speech': True}
# {'start': 22.08, 'end': 22.11, 'is_speech': True}
# {'start': 22.11, 'end': 22.14, 'is_speech': True}
# {'start': 22.14, 'end': 22.17, 'is_speech': True}
# {'start': 22.169999999999998, 'end': 22.2, 'is_speech': True}
# {'start': 22.2, 'end': 22.23, 'is_speech': True}
# {'start': 22.23, 'end': 22.26, 'is_speech': True}
# {'start': 22.259999999999998, 'end': 22.29, 'is_speech': True}
# {'start': 22.29, 'end': 22.32, 'is_speech': True}
# {'start': 22.32, 'end': 22.35, 'is_speech': True}
# {'start': 22.349999999999998, 'end': 22.38, 'is_speech': True}
# {'start': 22.38, 'end': 22.41, 'is_speech': True}
# {'start': 22.41, 'end': 22.44, 'is_speech': True}
# {'start': 22.439999999999998, 'end': 22.47, 'is_speech': True}
# {'start': 22.47, 'end': 22.5, 'is_speech': False}
# {'start': 22.5, 'end': 22.53, 'is_speech': False}
# {'start': 22.529999999999998, 'end': 22.56, 'is_speech': False}
# {'start': 22.56, 'end': 22.59, 'is_speech': False}
# {'start': 22.59, 'end': 22.62, 'is_speech': False}
# {'start': 22.619999999999997, 'end': 22.65, 'is_speech': False}
# {'start': 22.65, 'end': 22.68, 'is_speech': False}
# {'start': 22.68, 'end': 22.71, 'is_speech': False}
# {'start': 22.709999999999997, 'end': 22.74, 'is_speech': False}
# {'start': 22.74, 'end': 22.77, 'is_speech': False}
# {'start': 22.77, 'end': 22.8, 'is_speech': False}
# {'start': 22.799999999999997, 'end': 22.83, 'is_speech': False}
# {'start': 22.83, 'end': 22.86, 'is_speech': False}
# {'start': 22.86, 'end': 22.89, 'is_speech': False}
# {'start': 22.89, 'end': 22.92, 'is_speech': False}
# {'start': 22.919999999999998, 'end': 22.95, 'is_speech': False}
# {'start': 22.95, 'end': 22.98, 'is_speech': False}
# {'start': 22.98, 'end': 23.01, 'is_speech': False}
# {'start': 23.009999999999998, 'end': 23.04, 'is_speech': False}
# {'start': 23.04, 'end': 23.07, 'is_speech': True}
# {'start': 23.07, 'end': 23.1, 'is_speech': True}
# {'start': 23.099999999999998, 'end': 23.13, 'is_speech': True}
# {'start': 23.13, 'end': 23.16, 'is_speech': True}
# {'start': 23.16, 'end': 23.19, 'is_speech': True}
# {'start': 23.189999999999998, 'end': 23.22, 'is_speech': True}
# {'start': 23.22, 'end': 23.25, 'is_speech': True}
# {'start': 23.25, 'end': 23.28, 'is_speech': True}
# {'start': 23.279999999999998, 'end': 23.31, 'is_speech': True}
# {'start': 23.31, 'end': 23.34, 'is_speech': True}
# {'start': 23.34, 'end': 23.37, 'is_speech': True}
# {'start': 23.369999999999997, 'end': 23.4, 'is_speech': True}
# {'start': 23.4, 'end': 23.43, 'is_speech': True}
# {'start': 23.43, 'end': 23.46, 'is_speech': True}
# {'start': 23.459999999999997, 'end': 23.49, 'is_speech': True}
# {'start': 23.49, 'end': 23.52, 'is_speech': False}
# {'start': 23.52, 'end': 23.55, 'is_speech': False}
# {'start': 23.549999999999997, 'end': 23.58, 'is_speech': False}
# {'start': 23.58, 'end': 23.61, 'is_speech': False}
# {'start': 23.61, 'end': 23.64, 'is_speech': False}
# {'start': 23.64, 'end': 23.67, 'is_speech': False}
# {'start': 23.669999999999998, 'end': 23.7, 'is_speech': False}
# {'start': 23.7, 'end': 23.73, 'is_speech': False}
# {'start': 23.73, 'end': 23.76, 'is_speech': False}
# {'start': 23.759999999999998, 'end': 23.79, 'is_speech': False}
# {'start': 23.79, 'end': 23.82, 'is_speech': False}
# {'start': 23.82, 'end': 23.85, 'is_speech': True}
# {'start': 23.849999999999998, 'end': 23.88, 'is_speech': True}
# {'start': 23.88, 'end': 23.91, 'is_speech': True}
# {'start': 23.91, 'end': 23.94, 'is_speech': True}
# {'start': 23.939999999999998, 'end': 23.97, 'is_speech': False}
# {'start': 23.97, 'end': 24.0, 'is_speech': False}
# {'start': 24.0, 'end': 24.03, 'is_speech': False}
# {'start': 24.029999999999998, 'end': 24.06, 'is_speech': False}
# {'start': 24.06, 'end': 24.09, 'is_speech': False}
# {'start': 24.09, 'end': 24.12, 'is_speech': False}
# {'start': 24.119999999999997, 'end': 24.15, 'is_speech': False}
# {'start': 24.15, 'end': 24.18, 'is_speech': False}
# {'start': 24.18, 'end': 24.21, 'is_speech': False}
# {'start': 24.209999999999997, 'end': 24.24, 'is_speech': False}
# {'start': 24.24, 'end': 24.27, 'is_speech': False}
# {'start': 24.27, 'end': 24.3, 'is_speech': False}
# {'start': 24.299999999999997, 'end': 24.33, 'is_speech': False}
# {'start': 24.33, 'end': 24.36, 'is_speech': False}
# {'start': 24.36, 'end': 24.39, 'is_speech': True}
# {'start': 24.39, 'end': 24.42, 'is_speech': True}
# {'start': 24.419999999999998, 'end': 24.45, 'is_speech': True}
# {'start': 24.45, 'end': 24.48, 'is_speech': True}
# {'start': 24.48, 'end': 24.51, 'is_speech': True}
# {'start': 24.509999999999998, 'end': 24.54, 'is_speech': True}
# {'start': 24.54, 'end': 24.57, 'is_speech': True}
# {'start': 24.57, 'end': 24.6, 'is_speech': True}
# {'start': 24.599999999999998, 'end': 24.63, 'is_speech': True}
# {'start': 24.63, 'end': 24.66, 'is_speech': True}
# {'start': 24.66, 'end': 24.69, 'is_speech': True}
# {'start': 24.689999999999998, 'end': 24.72, 'is_speech': True}
# {'start': 24.72, 'end': 24.75, 'is_speech': False}
# {'start': 24.75, 'end': 24.78, 'is_speech': False}
# {'start': 24.779999999999998, 'end': 24.81, 'is_speech': False}
# {'start': 24.81, 'end': 24.84, 'is_speech': False}
# {'start': 24.84, 'end': 24.87, 'is_speech': False}
# {'start': 24.869999999999997, 'end': 24.9, 'is_speech': False}
# {'start': 24.9, 'end': 24.93, 'is_speech': False}
# {'start': 24.93, 'end': 24.96, 'is_speech': False}
# {'start': 24.959999999999997, 'end': 24.99, 'is_speech': False}
# {'start': 24.99, 'end': 25.02, 'is_speech': False}
# {'start': 25.02, 'end': 25.05, 'is_speech': False}
# {'start': 25.049999999999997, 'end': 25.08, 'is_speech': False}
# {'start': 25.08, 'end': 25.11, 'is_speech': False}
# {'start': 25.11, 'end': 25.14, 'is_speech': False}
# {'start': 25.14, 'end': 25.17, 'is_speech': False}
# {'start': 25.169999999999998, 'end': 25.2, 'is_speech': False}
# {'start': 25.2, 'end': 25.23, 'is_speech': False}
# {'start': 25.23, 'end': 25.26, 'is_speech': False}
# {'start': 25.259999999999998, 'end': 25.29, 'is_speech': False}
# {'start': 25.29, 'end': 25.32, 'is_speech': True}
# {'start': 25.32, 'end': 25.35, 'is_speech': True}
# {'start': 25.349999999999998, 'end': 25.38, 'is_speech': True}
# {'start': 25.38, 'end': 25.41, 'is_speech': True}
# {'start': 25.41, 'end': 25.44, 'is_speech': True}
# {'start': 25.439999999999998, 'end': 25.47, 'is_speech': True}
# {'start': 25.47, 'end': 25.5, 'is_speech': True}
# {'start': 25.5, 'end': 25.53, 'is_speech': False}
# {'start': 25.529999999999998, 'end': 25.56, 'is_speech': False}
# {'start': 25.56, 'end': 25.59, 'is_speech': False}
# {'start': 25.59, 'end': 25.62, 'is_speech': False}
# {'start': 25.619999999999997, 'end': 25.65, 'is_speech': True}
# {'start': 25.65, 'end': 25.68, 'is_speech': True}
# {'start': 25.68, 'end': 25.71, 'is_speech': True}
# {'start': 25.709999999999997, 'end': 25.74, 'is_speech': True}
# {'start': 25.74, 'end': 25.77, 'is_speech': False}
# {'start': 25.77, 'end': 25.8, 'is_speech': False}
# {'start': 25.799999999999997, 'end': 25.83, 'is_speech': False}
# {'start': 25.83, 'end': 25.86, 'is_speech': False}
# {'start': 25.86, 'end': 25.89, 'is_speech': False}
# {'start': 25.89, 'end': 25.92, 'is_speech': False}
# {'start': 25.919999999999998, 'end': 25.95, 'is_speech': False}
# {'start': 25.95, 'end': 25.98, 'is_speech': False}
# {'start': 25.98, 'end': 26.01, 'is_speech': False}
# {'start': 26.009999999999998, 'end': 26.04, 'is_speech': False}
# {'start': 26.04, 'end': 26.07, 'is_speech': False}
# {'start': 26.07, 'end': 26.1, 'is_speech': False}
# {'start': 26.099999999999998, 'end': 26.13, 'is_speech': False}
# {'start': 26.13, 'end': 26.16, 'is_speech': False}
# {'start': 26.16, 'end': 26.19, 'is_speech': False}
# {'start': 26.189999999999998, 'end': 26.22, 'is_speech': False}
# {'start': 26.22, 'end': 26.25, 'is_speech': False}
# {'start': 26.25, 'end': 26.28, 'is_speech': False}
# {'start': 26.279999999999998, 'end': 26.31, 'is_speech': True}
# {'start': 26.31, 'end': 26.34, 'is_speech': True}
# {'start': 26.34, 'end': 26.37, 'is_speech': True}
# {'start': 26.369999999999997, 'end': 26.4, 'is_speech': True}
# {'start': 26.4, 'end': 26.43, 'is_speech': True}
# {'start': 26.43, 'end': 26.46, 'is_speech': True}
# {'start': 26.459999999999997, 'end': 26.49, 'is_speech': False}
# {'start': 26.49, 'end': 26.52, 'is_speech': False}
# {'start': 26.52, 'end': 26.55, 'is_speech': False}
# {'start': 26.549999999999997, 'end': 26.58, 'is_speech': False}
# {'start': 26.58, 'end': 26.61, 'is_speech': False}
# ...
# {'start': 122.28, 'end': 122.31, 'is_speech': False}
# {'start': 122.31, 'end': 122.34, 'is_speech': False}
# {'start': 122.34, 'end': 122.37, 'is_speech': False}
# {'start': 122.37, 'end': 122.4, 'is_speech': False}
# {'start': 122.4, 'end': 122.43, 'is_speech': False}
# {'start': 122.42999999999999, 'end': 122.46, 'is_speech': False}
# {'start': 122.46, 'end': 122.49, 'is_speech': False}
# {'start': 122.49, 'end': 122.52, 'is_speech': False}
# {'start': 122.52, 'end': 122.55, 'is_speech': False}
# {'start': 122.55, 'end': 122.58, 'is_speech': True}
# {'start': 122.58, 'end': 122.61, 'is_speech': True}
# {'start': 122.61, 'end': 122.64, 'is_speech': True}
# {'start': 122.64, 'end': 122.67, 'is_speech': True}
# {'start': 122.67, 'end': 122.7, 'is_speech': False}
# {'start': 122.7, 'end': 122.73, 'is_speech': False}
# {'start': 122.73, 'end': 122.76, 'is_speech': False}
# {'start': 122.76, 'end': 122.79, 'is_speech': False}
# {'start': 122.78999999999999, 'end': 122.82, 'is_speech': False}
# {'start': 122.82, 'end': 122.85, 'is_speech': False}
# {'start': 122.85, 'end': 122.88, 'is_speech': False}
# {'start': 122.88, 'end': 122.91, 'is_speech': False}
# {'start': 122.91, 'end': 122.94, 'is_speech': False}
# {'start': 122.94, 'end': 122.97, 'is_speech': False}
# {'start': 122.97, 'end': 123.0, 'is_speech': False}
# {'start': 123.0, 'end': 123.03, 'is_speech': False}
# {'start': 123.03, 'end': 123.06, 'is_speech': False}
# {'start': 123.06, 'end': 123.09, 'is_speech': False}
# {'start': 123.09, 'end': 123.12, 'is_speech': False}
# {'start': 123.12, 'end': 123.15, 'is_speech': False}
# {'start': 123.15, 'end': 123.18, 'is_speech': False}
# {'start': 123.17999999999999, 'end': 123.21, 'is_speech': False}
# {'start': 123.21, 'end': 123.24, 'is_speech': False}
# {'start': 123.24, 'end': 123.27, 'is_speech': False}
# {'start': 123.27, 'end': 123.3, 'is_speech': False}
# {'start': 123.3, 'end': 123.33, 'is_speech': False}
# {'start': 123.33, 'end': 123.36, 'is_speech': False}
# {'start': 123.36, 'end': 123.39, 'is_speech': False}
# {'start': 123.39, 'end': 123.42, 'is_speech': False}
# {'start': 123.42, 'end': 123.45, 'is_speech': False}
# {'start': 123.45, 'end': 123.48, 'is_speech': False}
# {'start': 123.48, 'end': 123.51, 'is_speech': False}
# {'start': 123.51, 'end': 123.54, 'is_speech': True}
# {'start': 123.53999999999999, 'end': 123.57, 'is_speech': True}
# {'start': 123.57, 'end': 123.6, 'is_speech': True}
# {'start': 123.6, 'end': 123.63, 'is_speech': True}
# {'start': 123.63, 'end': 123.66, 'is_speech': False}
# {'start': 123.66, 'end': 123.69, 'is_speech': False}
# {'start': 123.69, 'end': 123.72, 'is_speech': False}
# {'start': 123.72, 'end': 123.75, 'is_speech': False}
# {'start': 123.75, 'end': 123.78, 'is_speech': False}
# {'start': 123.78, 'end': 123.81, 'is_speech': False}
# {'start': 123.81, 'end': 123.84, 'is_speech': False}
# {'start': 123.84, 'end': 123.87, 'is_speech': False}
# {'start': 123.87, 'end': 123.9, 'is_speech': False}
# {'start': 123.9, 'end': 123.93, 'is_speech': False}
# {'start': 123.92999999999999, 'end': 123.96, 'is_speech': False}
# {'start': 123.96, 'end': 123.99, 'is_speech': False}
# {'start': 123.99, 'end': 124.02, 'is_speech': False}
# {'start': 124.02, 'end': 124.05, 'is_speech': False}
# {'start': 124.05, 'end': 124.08, 'is_speech': False}
# {'start': 124.08, 'end': 124.11, 'is_speech': False}
# {'start': 124.11, 'end': 124.14, 'is_speech': False}
# {'start': 124.14, 'end': 124.17, 'is_speech': False}
# {'start': 124.17, 'end': 124.2, 'is_speech': False}
# {'start': 124.2, 'end': 124.23, 'is_speech': False}
# {'start': 124.23, 'end': 124.26, 'is_speech': False}
# {'start': 124.26, 'end': 124.29, 'is_speech': False}
# {'start': 124.28999999999999, 'end': 124.32, 'is_speech': False}
# {'start': 124.32, 'end': 124.35, 'is_speech': False}
# {'start': 124.35, 'end': 124.38, 'is_speech': True}
# {'start': 124.38, 'end': 124.41, 'is_speech': True}
# {'start': 124.41, 'end': 124.44, 'is_speech': True}
# {'start': 124.44, 'end': 124.47, 'is_speech': True}
# {'start': 124.47, 'end': 124.5, 'is_speech': True}
# {'start': 124.5, 'end': 124.53, 'is_speech': True}
# {'start': 124.53, 'end': 124.56, 'is_speech': False}
# {'start': 124.56, 'end': 124.59, 'is_speech': False}
# {'start': 124.59, 'end': 124.62, 'is_speech': False}
# {'start': 124.62, 'end': 124.65, 'is_speech': False}
# {'start': 124.65, 'end': 124.68, 'is_speech': False}
# {'start': 124.67999999999999, 'end': 124.71, 'is_speech': False}
# {'start': 124.71, 'end': 124.74, 'is_speech': False}
# {'start': 124.74, 'end': 124.77, 'is_speech': False}
# {'start': 124.77, 'end': 124.8, 'is_speech': False}
# {'start': 124.8, 'end': 124.83, 'is_speech': False}
# {'start': 124.83, 'end': 124.86, 'is_speech': False}
# {'start': 124.86, 'end': 124.89, 'is_speech': False}
# {'start': 124.89, 'end': 124.92, 'is_speech': False}
# {'start': 124.92, 'end': 124.95, 'is_speech': False}
# {'start': 124.95, 'end': 124.98, 'is_speech': False}
# {'start': 124.98, 'end': 125.01, 'is_speech': False}
# {'start': 125.01, 'end': 125.04, 'is_speech': False}
# {'start': 125.03999999999999, 'end': 125.07, 'is_speech': False}
# {'start': 125.07, 'end': 125.1, 'is_speech': False}
# {'start': 125.1, 'end': 125.13, 'is_speech': False}
# {'start': 125.13, 'end': 125.16, 'is_speech': False}
# {'start': 125.16, 'end': 125.19, 'is_speech': False}
# {'start': 125.19, 'end': 125.22, 'is_speech': False}
# {'start': 125.22, 'end': 125.25, 'is_speech': False}
# {'start': 125.25, 'end': 125.28, 'is_speech': False}
# {'start': 125.28, 'end': 125.31, 'is_speech': False}
# {'start': 125.31, 'end': 125.34, 'is_speech': True}
# {'start': 125.34, 'end': 125.37, 'is_speech': True}
# {'start': 125.37, 'end': 125.4, 'is_speech': True}
# {'start': 125.4, 'end': 125.43, 'is_speech': True}
# {'start': 125.42999999999999, 'end': 125.46, 'is_speech': False}
# {'start': 125.46, 'end': 125.49, 'is_speech': False}
# {'start': 125.49, 'end': 125.52, 'is_speech': False}
# {'start': 125.52, 'end': 125.55, 'is_speech': False}
# {'start': 125.55, 'end': 125.58, 'is_speech': False}
# {'start': 125.58, 'end': 125.61, 'is_speech': False}
# {'start': 125.61, 'end': 125.64, 'is_speech': False}
# {'start': 125.64, 'end': 125.67, 'is_speech': False}
# {'start': 125.67, 'end': 125.7, 'is_speech': False}
# {'start': 125.7, 'end': 125.73, 'is_speech': False}
# {'start': 125.73, 'end': 125.76, 'is_speech': False}
# {'start': 125.76, 'end': 125.79, 'is_speech': False}
# {'start': 125.78999999999999, 'end': 125.82, 'is_speech': False}
# {'start': 125.82, 'end': 125.85, 'is_speech': False}
# {'start': 125.85, 'end': 125.88, 'is_speech': False}
# {'start': 125.88, 'end': 125.91, 'is_speech': False}
# {'start': 125.91, 'end': 125.94, 'is_speech': False}
# {'start': 125.94, 'end': 125.97, 'is_speech': False}
# {'start': 125.97, 'end': 126.0, 'is_speech': False}
# {'start': 126.0, 'end': 126.03, 'is_speech': False}
# {'start': 126.03, 'end': 126.06, 'is_speech': False}
# {'start': 126.06, 'end': 126.09, 'is_speech': False}
# {'start': 126.09, 'end': 126.12, 'is_speech': False}
# {'start': 126.12, 'end': 126.15, 'is_speech': False}
# {'start': 126.15, 'end': 126.18, 'is_speech': False}
# {'start': 126.17999999999999, 'end': 126.21, 'is_speech': False}
# {'start': 126.21, 'end': 126.24, 'is_speech': False}
# {'start': 126.24, 'end': 126.27, 'is_speech': False}
# {'start': 126.27, 'end': 126.3, 'is_speech': False}
# {'start': 126.3, 'end': 126.33, 'is_speech': False}
# {'start': 126.33, 'end': 126.36, 'is_speech': False}
# {'start': 126.36, 'end': 126.39, 'is_speech': False}
# {'start': 126.39, 'end': 126.42, 'is_speech': False}
# {'start': 126.42, 'end': 126.45, 'is_speech': False}
# {'start': 126.45, 'end': 126.48, 'is_speech': False}
# {'start': 126.48, 'end': 126.51, 'is_speech': False}
# {'start': 126.51, 'end': 126.54, 'is_speech': False}
# {'start': 126.53999999999999, 'end': 126.57, 'is_speech': False}
# {'start': 126.57, 'end': 126.6, 'is_speech': True}
# {'start': 126.6, 'end': 126.63, 'is_speech': True}
# {'start': 126.63, 'end': 126.66, 'is_speech': True}
# {'start': 126.66, 'end': 126.69, 'is_speech': True}
# {'start': 126.69, 'end': 126.72, 'is_speech': True}
# {'start': 126.72, 'end': 126.75, 'is_speech': True}
# {'start': 126.75, 'end': 126.78, 'is_speech': True}
# {'start': 126.78, 'end': 126.81, 'is_speech': True}
# {'start': 126.81, 'end': 126.84, 'is_speech': True}
# {'start': 126.84, 'end': 126.87, 'is_speech': False}
# {'start': 126.87, 'end': 126.9, 'is_speech': False}
# {'start': 126.9, 'end': 126.93, 'is_speech': False}
# {'start': 126.92999999999999, 'end': 126.96, 'is_speech': False}
# {'start': 126.96, 'end': 126.99, 'is_speech': False}
# {'start': 126.99, 'end': 127.02, 'is_speech': False}
# {'start': 127.02, 'end': 127.05, 'is_speech': False}
# {'start': 127.05, 'end': 127.08, 'is_speech': False}
# {'start': 127.08, 'end': 127.11, 'is_speech': False}
# {'start': 127.11, 'end': 127.14, 'is_speech': False}
# {'start': 127.14, 'end': 127.17, 'is_speech': False}
# {'start': 127.17, 'end': 127.2, 'is_speech': False}
# {'start': 127.2, 'end': 127.23, 'is_speech': False}
# {'start': 127.23, 'end': 127.26, 'is_speech': False}
# {'start': 127.26, 'end': 127.29, 'is_speech': False}
# {'start': 127.28999999999999, 'end': 127.32, 'is_speech': False}
# {'start': 127.32, 'end': 127.35, 'is_speech': False}
# {'start': 127.35, 'end': 127.38, 'is_speech': False}
# {'start': 127.38, 'end': 127.41, 'is_speech': False}
# {'start': 127.41, 'end': 127.44, 'is_speech': False}
# {'start': 127.44, 'end': 127.47, 'is_speech': False}
# {'start': 127.47, 'end': 127.5, 'is_speech': False}
# {'start': 127.5, 'end': 127.53, 'is_speech': False}
# {'start': 127.53, 'end': 127.56, 'is_speech': False}
# {'start': 127.56, 'end': 127.59, 'is_speech': False}
# {'start': 127.59, 'end': 127.62, 'is_speech': False}
# {'start': 127.62, 'end': 127.65, 'is_speech': False}
# {'start': 127.65, 'end': 127.68, 'is_speech': False}
# {'start': 127.67999999999999, 'end': 127.71, 'is_speech': False}
# {'start': 127.71, 'end': 127.74, 'is_speech': True}
# {'start': 127.74, 'end': 127.77, 'is_speech': True}
# {'start': 127.77, 'end': 127.8, 'is_speech': True}
# {'start': 127.8, 'end': 127.83, 'is_speech': True}
# {'start': 127.83, 'end': 127.86, 'is_speech': True}
# {'start': 127.86, 'end': 127.89, 'is_speech': True}
# {'start': 127.89, 'end': 127.92, 'is_speech': True}
# {'start': 127.92, 'end': 127.95, 'is_speech': True}
# {'start': 127.95, 'end': 127.98, 'is_speech': True}
# {'start': 127.97999999999999, 'end': 128.01, 'is_speech': True}
# {'start': 128.01, 'end': 128.04, 'is_speech': True}
# {'start': 128.04, 'end': 128.07, 'is_speech': True}
# {'start': 128.07, 'end': 128.1, 'is_speech': True}
# {'start': 128.1, 'end': 128.13, 'is_speech': True}
# {'start': 128.13, 'end': 128.16, 'is_speech': True}
# {'start': 128.16, 'end': 128.19, 'is_speech': True}
# {'start': 128.19, 'end': 128.22, 'is_speech': True}
# {'start': 128.22, 'end': 128.25, 'is_speech': False}
# {'start': 128.25, 'end': 128.28, 'is_speech': True}
# {'start': 128.28, 'end': 128.31, 'is_speech': True}
# {'start': 128.31, 'end': 128.34, 'is_speech': True}
# {'start': 128.34, 'end': 128.37, 'is_speech': True}
# {'start': 128.37, 'end': 128.4, 'is_speech': True}
# {'start': 128.4, 'end': 128.43, 'is_speech': True}
# {'start': 128.43, 'end': 128.46, 'is_speech': False}
# {'start': 128.46, 'end': 128.49, 'is_speech': False}
# {'start': 128.49, 'end': 128.52, 'is_speech': False}
# {'start': 128.52, 'end': 128.55, 'is_speech': False}
# {'start': 128.55, 'end': 128.58, 'is_speech': False}
# {'start': 128.58, 'end': 128.61, 'is_speech': False}
# {'start': 128.60999999999999, 'end': 128.64, 'is_speech': False}
# {'start': 128.64, 'end': 128.67, 'is_speech': False}
# {'start': 128.67, 'end': 128.7, 'is_speech': False}
# {'start': 128.7, 'end': 128.73, 'is_speech': False}
# {'start': 128.73, 'end': 128.76, 'is_speech': False}
# {'start': 128.76, 'end': 128.79, 'is_speech': False}
# {'start': 128.79, 'end': 128.82, 'is_speech': False}
# {'start': 128.82, 'end': 128.85, 'is_speech': False}
# {'start': 128.85, 'end': 128.88, 'is_speech': False}
# {'start': 128.88, 'end': 128.91, 'is_speech': False}
# {'start': 128.91, 'end': 128.94, 'is_speech': False}
# {'start': 128.94, 'end': 128.97, 'is_speech': False}
# {'start': 128.97, 'end': 129.0, 'is_speech': False}
# {'start': 129.0, 'end': 129.03, 'is_speech': False}
# {'start': 129.03, 'end': 129.06, 'is_speech': False}
# {'start': 129.06, 'end': 129.09, 'is_speech': False}
# {'start': 129.09, 'end': 129.12, 'is_speech': False}
# {'start': 129.12, 'end': 129.15, 'is_speech': False}
# {'start': 129.15, 'end': 129.18, 'is_speech': False}
# {'start': 129.18, 'end': 129.21, 'is_speech': False}
# {'start': 129.21, 'end': 129.24, 'is_speech': False}
# {'start': 129.24, 'end': 129.27, 'is_speech': False}
# {'start': 129.27, 'end': 129.3, 'is_speech': False}
# {'start': 129.3, 'end': 129.33, 'is_speech': False}
# {'start': 129.33, 'end': 129.36, 'is_speech': False}
# {'start': 129.35999999999999, 'end': 129.39, 'is_speech': False}
# {'start': 129.39, 'end': 129.42, 'is_speech': False}
# {'start': 129.42, 'end': 129.45, 'is_speech': False}
# {'start': 129.45, 'end': 129.48, 'is_speech': False}
# {'start': 129.48, 'end': 129.51, 'is_speech': False}
# {'start': 129.51, 'end': 129.54, 'is_speech': False}
# {'start': 129.54, 'end': 129.57, 'is_speech': False}
# {'start': 129.57, 'end': 129.6, 'is_speech': False}
# {'start': 129.6, 'end': 129.63, 'is_speech': False}
# {'start': 129.63, 'end': 129.66, 'is_speech': False}
# {'start': 129.66, 'end': 129.69, 'is_speech': False}
# {'start': 129.69, 'end': 129.72, 'is_speech': False}
# {'start': 129.72, 'end': 129.75, 'is_speech': False}
# {'start': 129.75, 'end': 129.78, 'is_speech': False}
# {'start': 129.78, 'end': 129.81, 'is_speech': False}
# {'start': 129.81, 'end': 129.84, 'is_speech': False}
# {'start': 129.84, 'end': 129.87, 'is_speech': False}
# {'start': 129.87, 'end': 129.9, 'is_speech': False}
# {'start': 129.9, 'end': 129.93, 'is_speech': False}
# {'start': 129.93, 'end': 129.96, 'is_speech': False}
# {'start': 129.96, 'end': 129.99, 'is_speech': False}
# {'start': 129.99, 'end': 130.02, 'is_speech': False}
# {'start': 130.02, 'end': 130.05, 'is_speech': False}
# {'start': 130.05, 'end': 130.08, 'is_speech': False}
# {'start': 130.08, 'end': 130.11, 'is_speech': False}
# {'start': 130.10999999999999, 'end': 130.14, 'is_speech': False}
# {'start': 130.14, 'end': 130.17, 'is_speech': False}
# {'start': 130.17, 'end': 130.2, 'is_speech': False}
# {'start': 130.2, 'end': 130.23, 'is_speech': False}
# {'start': 130.23, 'end': 130.26, 'is_speech': False}
# {'start': 130.26, 'end': 130.29, 'is_speech': False}
# {'start': 130.29, 'end': 130.32, 'is_speech': False}
# {'start': 130.32, 'end': 130.35, 'is_speech': False}
# {'start': 130.35, 'end': 130.38, 'is_speech': False}
# {'start': 130.38, 'end': 130.41, 'is_speech': False}
# {'start': 130.41, 'end': 130.44, 'is_speech': False}
# {'start': 130.44, 'end': 130.47, 'is_speech': False}
# {'start': 130.47, 'end': 130.5, 'is_speech': False}
# {'start': 130.5, 'end': 130.53, 'is_speech': False}
# {'start': 130.53, 'end': 130.56, 'is_speech': False}
# {'start': 130.56, 'end': 130.59, 'is_speech': False}
# {'start': 130.59, 'end': 130.62, 'is_speech': False}
# {'start': 130.62, 'end': 130.65, 'is_speech': False}
# {'start': 130.65, 'end': 130.68, 'is_speech': False}
# {'start': 130.68, 'end': 130.71, 'is_speech': False}
# {'start': 130.71, 'end': 130.74, 'is_speech': False}
# {'start': 130.74, 'end': 130.77, 'is_speech': False}
# {'start': 130.77, 'end': 130.8, 'is_speech': False}
# {'start': 130.8, 'end': 130.83, 'is_speech': False}
# {'start': 130.83, 'end': 130.86, 'is_speech': False}
# {'start': 130.85999999999999, 'end': 130.89, 'is_speech': False}
# {'start': 130.89, 'end': 130.92, 'is_speech': False}
# {'start': 130.92, 'end': 130.95, 'is_speech': False}
# {'start': 130.95, 'end': 130.98, 'is_speech': False}
# {'start': 130.98, 'end': 131.01, 'is_speech': False}
# {'start': 131.01, 'end': 131.04, 'is_speech': False}
# {'start': 131.04, 'end': 131.07, 'is_speech': False}
# {'start': 131.07, 'end': 131.1, 'is_speech': False}
# {'start': 131.1, 'end': 131.13, 'is_speech': False}
# {'start': 131.13, 'end': 131.16, 'is_speech': False}
# {'start': 131.16, 'end': 131.19, 'is_speech': False}
# {'start': 131.19, 'end': 131.22, 'is_speech': False}
# {'start': 131.22, 'end': 131.25, 'is_speech': False}

# %% [markdown]
# ### Creating new file without speech.

# %%
# Create a new audio file with only the speech segments, using the process_audio function

def save_speech(audio_file, output_file, segments):
    with wave.open(audio_file, 'rb') as wf:
        sample_width = wf.getsampwidth()
        sample_rate = wf.getframerate()
        n_channels = wf.getnchannels()
        
        with wave.open(output_file, 'wb') as output_wf:
            output_wf.setnchannels(n_channels)
            output_wf.setsampwidth(sample_width)
            output_wf.setframerate(sample_rate)
            
            for segment in segments:
                if segment['is_speech']:
                    wf.setpos(int(segment['start'] * sample_rate))
                    output_wf.writeframes(wf.readframes(int((segment['end'] - segment['start']) * sample_rate)))

# Process the audio file

audio_file = "../_data/audio/all_sessions/session_18"

# Save the speech segments to a new audio file
save_speech(f'{audio_file}.wav', f'{audio_file}_speech.wav' , process_audio(f'{audio_file}.wav'))
